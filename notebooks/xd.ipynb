# %% [markdown]
# # Batch Run + Evaluation for Ticket Categorization
#
# This notebook:
# 1. Loads your taxonomy RAG pipeline from `graph_agent_taxonomy_rag.py` (from the canvas).
# 2. Runs it over `dataset_for_categorization.csv` with columns **Case ID, ticket, employee**.
# 3. Saves predictions to `predictions_with_pipeline.csv`.
# 4. Evaluates against the **noisy** `employee` column by detecting which tier (Domain/Cat1/Cat2/Cat3) the employee label belongs to and comparing at that tier.
# 5. Prints summary metrics and a confusion matrix for the top Cat3 classes.
#
# > Note: `employee` labels are ~50–70% accurate and may be inconsistent. Treat these metrics as **agreement with the existing process**, not absolute ground truth.

# %% [markdown]
# ## 0) (Optional) Install dependencies

# %%
# If you're in a clean environment, uncomment:
# !pip install -q langgraph langchain langchain-google-genai langchain-community faiss-cpu rank_bm25 pandas python-dotenv langfuse scikit-learn tqdm

# %% [markdown]
# ## 1) Imports & configuration

# %%
import os

os.environ.setdefault("GRPC_VERBOSITY", "NONE")
os.environ.setdefault("GLOG_minloglevel", "2")
import json
import time
from pathlib import Path

import pandas as pd
from tqdm import tqdm

# For evaluation
import numpy as np
from collections import Counter
from sklearn.metrics import confusion_matrix

# Import your pipeline (make sure the file exists locally)
from src.seq_all_rag import run_pipeline

# ---- Paths ----
DATASET_CSV = "data/evaluation_dataset2.csv"  # input with Case ID, ticket, employee
TAXONOMY_CSV = "data/cleaned.csv"  # your taxonomy file
OUTPUT_PRED_CSV = "data/predictions_with_pipeline.csv"

# ---- Controls ----
TICKET_MAX_CHARS = 2000  # truncate very long tickets (head+tail kept below)
HEAD_KEEP = 1400
TAIL_KEEP = 600
SLEEP_BETWEEN = 0.0  # set to small number if you want to throttle requests

# Optional: set your env vars for Google + Langfuse before running (or via .env file)
# os.environ["GOOGLE_API_KEY"] = "...."
# os.environ["LANGFUSE_PUBLIC_KEY"] = "...."
# os.environ["LANGFUSE_SECRET_KEY"] = "...."
# os.environ["LANGFUSE_HOST"] = "https://cloud.langfuse.com"

# %% [markdown]
# ## 2) Helpers (truncation, normalization, tier detection)

# %%
def truncate_ticket(
    text: str, max_chars=TICKET_MAX_CHARS, head_keep=HEAD_KEEP, tail_keep=TAIL_KEEP
) -> str:
    if not isinstance(text, str):
        return ""
    text = text.strip()
    if len(text) <= max_chars:
        return text
    head = text[:head_keep]
    tail = text[-tail_keep:]
    return head + "\n...\n" + tail


def normalize_label(s):
    if not isinstance(s, str):
        return ""
    return " ".join(s.strip().split())  # collapse multiple spaces


# Load taxonomy and build lookup sets to detect which tier a label belongs to
tax = pd.read_csv(TAXONOMY_CSV).fillna("")
for col in ["Domain", "Cat1", "Cat2", "Cat3"]:
    if col in tax.columns:
        tax[col] = tax[col].astype(str).str.strip()

DOMAINS = set(tax["Domain"].unique().tolist())
CAT1S = set(tax["Cat1"].unique().tolist())
CAT2S = set(tax["Cat2"].unique().tolist())
CAT3S = set(tax["Cat3"].unique().tolist())


def detect_employee_tier(emp_label: str):
    lab = normalize_label(emp_label)
    if lab in CAT3S:
        return "Cat3"
    if lab in CAT2S:
        return "Cat2"
    if lab in CAT1S:
        return "Cat1"
    if lab in DOMAINS:
        return "Domain"
    return None


# Optional: for confusion matrices, get the full list of Cat3 labels
ALL_CAT3 = sorted(list(CAT3S))
cat3_to_idx = {c: i for i, c in enumerate(ALL_CAT3)}

# %% [markdown]
# ## 3) Batch run pipeline over dataset

# %%
df = pd.read_csv(DATASET_CSV).fillna("")
assert set(["case_id", "case", "ajiltan"]).issubset(
    df.columns
), "Input CSV must have columns: case_id, case, ajiltan"

pred_rows = []
for _, row in tqdm(df.iterrows(), total=len(df)):
    case_id = row["case_id"]
    ticket_text = truncate_ticket(row["case"])
    try:
        out = run_pipeline(ticket_text, TAXONOMY_CSV)
        pred_rows.append(
            {
                "case_id": case_id,  # <-- consistent key
                "pred_domain": out.get("domain", ""),
                "pred_cat1": out.get("category_1", ""),
                "pred_cat2": out.get("category_2", ""),
                "pred_cat3": out.get("category_3", ""),
            }
        )
    except Exception as e:
        pred_rows.append(
            {
                "case_id": case_id,  # <-- consistent key
                "pred_domain": "",
                "pred_cat1": "",
                "pred_cat2": "",
                "pred_cat3": "",
                "error": str(e),
            }
        )
    if SLEEP_BETWEEN > 0:
        time.sleep(SLEEP_BETWEEN)

pred_df = pd.DataFrame(pred_rows)
out_df = df.merge(pred_df, on="case_id", how="left")
out_df.to_csv(OUTPUT_PRED_CSV, index=False)
out_df.head()
# Out:
#   0%|          | 0/21 [00:00<?, ?it/s]WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1760338734.427080  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338734.430147  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338735.613568  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338736.437708  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338736.438896  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338737.656805  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338738.444014  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338738.444773  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338739.534103  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338740.322808  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338740.324030  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338741.364341  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
#   5%|▍         | 1/21 [00:09<03:00,  9.03s/it]E0000 00:00:1760338743.448678  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338743.449221  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338744.811799  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338745.550503  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338745.551303  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338746.663132  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338747.704413  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338747.705169  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338749.028545  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338749.832360  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338749.832920  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338751.169933  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
#  10%|▉         | 2/21 [00:18<02:52,  9.09s/it]E0000 00:00:1760338752.589497  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338752.589844  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338753.651201  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338754.409406  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338754.410198  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338755.495535  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338756.265688  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338756.266251  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338757.521084  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
#  14%|█▍        | 3/21 [00:24<02:22,  7.89s/it]E0000 00:00:1760338759.045490  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338759.046077  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338760.279720  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338761.094041  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338761.094818  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338762.234619  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338763.137908  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338763.138851  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338764.329531  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338765.234617  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338765.234972  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338766.510995  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
#  19%|█▉        | 4/21 [00:33<02:23,  8.42s/it]E0000 00:00:1760338768.296038  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338768.296577  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338769.513346  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338770.442333  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338770.442980  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338771.694885  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338772.405471  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338772.406472  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338773.596760  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338774.381883  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338774.382426  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338775.695578  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
#  24%|██▍       | 5/21 [00:42<02:18,  8.64s/it]E0000 00:00:1760338777.310977  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338777.311333  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338778.430021  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338779.112653  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338779.113391  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338780.258577  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338781.069514  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338781.069980  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338782.321837  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338783.245675  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338783.246212  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338784.515535  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
#  29%|██▊       | 6/21 [00:51<02:09,  8.64s/it]E0000 00:00:1760338785.957246  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338785.957745  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338787.066393  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338787.906799  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338787.907781  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338788.986492  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338789.866067  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338789.866999  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338790.987223  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338791.921461  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338791.921836  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338793.121401  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
#  33%|███▎      | 7/21 [01:00<02:01,  8.69s/it]E0000 00:00:1760338794.747629  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338794.748022  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338795.732015  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338796.684967  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338796.685723  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338797.804520  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338798.562215  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338798.563288  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338799.752760  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338800.570229  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338800.571019  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338801.647812  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
#  38%|███▊      | 8/21 [01:08<01:50,  8.54s/it]E0000 00:00:1760338802.953745  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338802.954332  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338804.256449  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338805.060819  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338805.061585  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338806.298359  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338807.177402  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338807.178556  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338808.466474  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
#  43%|████▎     | 9/21 [01:15<01:36,  8.06s/it]E0000 00:00:1760338809.966034  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338809.966551  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338811.129461  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338811.854940  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338811.855861  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338813.036968  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338813.933678  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338813.934485  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338815.469271  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338816.373107  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338816.373894  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338817.798959  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
#  48%|████▊     | 10/21 [01:24<01:32,  8.41s/it]E0000 00:00:1760338819.156401  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338819.156798  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338820.487253  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338821.423721  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338821.424484  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338822.525802  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338823.361319  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338823.362119  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338824.527825  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338825.381500  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338825.381961  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338826.564732  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
#  52%|█████▏    | 11/21 [01:33<01:25,  8.60s/it]E0000 00:00:1760338828.176329  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338828.176750  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338829.324228  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338830.199485  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338830.200465  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338831.455289  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338832.337978  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338832.339259  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338833.505106  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338834.359828  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338834.360610  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338835.374705  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
#  57%|█████▋    | 12/21 [01:42<01:17,  8.65s/it]E0000 00:00:1760338836.944441  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338836.944927  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338837.966704  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338838.920413  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338838.921180  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338840.013758  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338840.897196  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338840.897776  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338841.899006  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
#  62%|██████▏   | 13/21 [01:48<01:03,  7.94s/it]E0000 00:00:1760338843.267925  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338843.268446  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338844.427342  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338845.313771  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338845.314304  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338846.373160  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338847.360043  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338847.360394  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338848.669948  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
#  67%|██████▋   | 14/21 [01:55<00:53,  7.68s/it]E0000 00:00:1760338850.344483  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338850.345056  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338851.488664  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338852.252348  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338852.252876  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338853.644829  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338854.494327  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338854.495272  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338855.631356  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338856.515632  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338856.516380  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338857.868171  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
#  71%|███████▏  | 15/21 [02:04<00:48,  8.08s/it]E0000 00:00:1760338859.346309  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338859.346674  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338860.563800  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338861.428093  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338861.428971  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338862.600549  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338863.356488  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338863.357407  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338864.530851  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
#  76%|███████▌  | 16/21 [02:11<00:38,  7.69s/it]E0000 00:00:1760338866.116868  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338866.117845  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338867.208176  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338867.905747  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338867.906291  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338869.047238  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338869.900632  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338869.901780  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338871.266331  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338872.052771  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338872.053537  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338873.198346  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
#  81%|████████  | 17/21 [02:20<00:31,  7.99s/it]E0000 00:00:1760338874.820160  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338874.821099  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338876.155384  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338876.913519  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338876.914076  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338878.207591  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338878.953860  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338878.954840  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338880.176638  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338880.949278  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338880.950509  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338882.478351  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
#  86%|████████▌ | 18/21 [02:30<00:25,  8.50s/it]E0000 00:00:1760338884.512141  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338884.513143  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338885.675831  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338886.492252  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338886.493073  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338887.694091  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338888.498476  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338888.499388  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338889.701267  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338890.373264  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338890.375589  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338891.708769  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
#  90%|█████████ | 19/21 [02:38<00:17,  8.62s/it]E0000 00:00:1760338893.416491  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338893.416889  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338894.711813  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338895.627120  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338895.627966  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338896.915527  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338897.800372  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338897.800891  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338898.992408  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338900.044960  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338900.045446  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338901.087811  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
#  95%|█████████▌| 20/21 [02:48<00:08,  8.82s/it]E0000 00:00:1760338902.682444  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338902.682951  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338903.938726  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338904.809928  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338904.810475  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338906.074430  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338906.946943  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338906.947936  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1760338908.171170  890740 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# 100%|██████████| 21/21 [02:55<00:00,  8.35s/it]
#    case_id                                               case  \
# 0   145075  Gantuya': "Туслах цэс"\n'Unitel': "U-Bot-с хэр...
# 1   145050  Dx Bataa Baynmynkh Bataa': "Sain bnuu"\n'Unite...
# 2   145034  Altbazar Altansarnai': "Үглээ юнитэл"\n'Unitel...
# 3   144958  Б. Нансалмаа': "Туслах цэс"\n'Unitel': "U-Bot-...
# 4   144952  Н. Энжи': "Get started"\n'Н. Энжи': "Ажилтанта...
#
#                                              ajiltan pred_domain  \
# 0  Mobile > Үндсэн үйлчилгээ > Багц солихтой холб...      Mobile
# 1        Mobile > Дугаар > Дагалдах эрхтэй холбоотой      Mobile
# 2  Mobile > Үндсэн үйлчилгээ > Гар утасны тохирго...      Mobile
# 3         Mobile > Дугаар > Пин пук кодтой холбоотой      Mobile
# 4  Mobile > Үндсэн үйлчилгээ > Гар утас лизингтэй...      Mobile
#
#           pred_cat1                          pred_cat2  \
# 0              Дата          Дата багцуудтай холбоотой
# 1            Дугаар  Дугаар хааж, нээлгэхтэй холбоотой
# 2  Үндсэн үйлчилгээ   Гар утасны тохиргоотой холбоотой
# 3            Дугаар           Сим сэргээхтэй холбоотой
# 4             Бусад         Digital сувагтай холбоотой
#
#                                            pred_cat3
# 0  L2- Дата багцын үнийн дүн зөрүүтэй харагдсанаа...
# 1                            P-Дугаар нээлгэх хүсэлт
# 2
# 3  L2-Unitel app сим сэргээхэд амжилтгүй алдаа за...
# 4  L2-Лизингийн хугацаа дууссан ч багц хооронд ши...

# %% [markdown]
# ## 4) Evaluation (agreement vs. employee labels)

# %%
out_df = pd.read_csv(OUTPUT_PRED_CSV).fillna("")
out_df["employee_norm"] = out_df["ajiltan"].apply(normalize_label)
out_df["emp_tier"] = out_df["employee_norm"].apply(detect_employee_tier)


def compare_at_tier(row):
    tier = row["emp_tier"]
    emp = row["employee_norm"]
    if tier == "Domain":
        return emp == normalize_label(row.get("pred_domain", ""))
    if tier == "Cat1":
        return emp == normalize_label(row.get("pred_cat1", ""))
    if tier == "Cat2":
        return emp == normalize_label(row.get("pred_cat2", ""))
    if tier == "Cat3":
        return emp == normalize_label(row.get("pred_cat3", ""))
    return False


out_df["match_at_emp_tier"] = out_df.apply(compare_at_tier, axis=1)

summary = (
    out_df.groupby("emp_tier")["match_at_emp_tier"]
    .agg(["count", "mean"])
    .rename(columns={"mean": "accuracy"})
)
summary.loc["ALL"] = [len(out_df), out_df["match_at_emp_tier"].mean()]
summary
# Out:
#           count  accuracy
# emp_tier
# ALL        21.0       0.0

# %% [markdown]
# ### 4.1 Breakdown by Domain (using predicted domain)

# %%
by_domain = (
    out_df.groupby("pred_domain")["match_at_emp_tier"]
    .agg(["count", "mean"])
    .rename(columns={"mean": "agreement"})
    .sort_values("count", ascending=False)
)
by_domain.head(20)
# Out:
#              count  agreement
# pred_domain
# Mobile          18        0.0
# Toki             2        0.0
# IPTV             1        0.0

# %% [markdown]
# ### 4.2 Confusion matrix for Cat3 (top classes only)

# %%
cat3_rows = out_df[out_df["emp_tier"] == "Cat3"].copy()
TOP_N = 40
top_emp_cat3 = cat3_rows["employee_norm"].value_counts().head(TOP_N).index.tolist()
cm_df = cat3_rows[cat3_rows["employee_norm"].isin(top_emp_cat3)].copy()

from sklearn.metrics import confusion_matrix

y_true = [normalize_label(x) for x in cm_df["employee_norm"].tolist()]
y_pred = [normalize_label(x) for x in cm_df["pred_cat3"].tolist()]

labels = sorted(list(set(top_emp_cat3 + list(set(y_pred)))))
cm = confusion_matrix(y_true, y_pred, labels=labels)
cm_df_out = pd.DataFrame(
    cm, index=[f"T:{l}" for l in labels], columns=[f"P:{l}" for l in labels]
)
cm_df_out.head(20)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 12
#       9 y_pred = [normalize_label(x) for x in cm_df["pred_cat3"].tolist()]
#      11 labels = sorted(list(set(top_emp_cat3 + list(set(y_pred)))))
# ---> 12 cm = confusion_matrix(y_true, y_pred, labels=labels)
#      13 cm_df_out = pd.DataFrame(
#      14     cm, index=[f"T:{l}" for l in labels], columns=[f"P:{l}" for l in labels]
#      15 )
#      16 cm_df_out.head(20)
#
# File /opt/conda/lib/python3.13/site-packages/sklearn/utils/_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File /opt/conda/lib/python3.13/site-packages/sklearn/metrics/_classification.py:477, in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     475 n_labels = labels.size
#     476 if n_labels == 0:
# --> 477     raise ValueError("'labels' should contains at least one label.")
#     478 elif y_true.size == 0:
#     479     return np.zeros((n_labels, n_labels), dtype=int)
#
# ValueError: 'labels' should contains at least one label.

# %%
from sklearn.metrics import confusion_matrix, classification_report
import pandas as pd


def safe_normalize(x):
    s = normalize_label(x)
    return "∅" if s == "" else s


def cat3_confusion_and_report(out_df, top_n=40):
    df = out_df.copy().fillna("")
    if "emp_tier" not in df.columns:
        df["employee_norm"] = df["ajiltan"].apply(normalize_label)
        df["emp_tier"] = df["employee_norm"].apply(detect_employee_tier)

    cat3_rows = df[df["emp_tier"] == "Cat3"].copy()
    if cat3_rows.empty:
        print("No rows where employee label is Cat3 — skipping confusion matrix.")
        return (None, None, None)

    cat3_rows["y_true"] = cat3_rows["employee_norm"].apply(safe_normalize)
    cat3_rows["y_pred"] = cat3_rows["pred_cat3"].apply(safe_normalize)

    # Apply top-N; if it drops everything, fall back to ALL
    if top_n is not None:
        true_counts = cat3_rows["y_true"].value_counts()
        keep = set(true_counts.head(top_n).index.tolist())
        cm_df = cat3_rows[cat3_rows["y_true"].isin(keep)].copy()
        if cm_df.empty:  # fallback
            cm_df = cat3_rows
    else:
        cm_df = cat3_rows

    y_true = cm_df["y_true"].tolist()
    y_pred = cm_df["y_pred"].tolist()
    labels = sorted(set(y_true) | set(y_pred))

    if len(labels) == 0:
        print("Zero labels to evaluate even after fallback.")
        return (None, None, None)

    cm = confusion_matrix(y_true, y_pred, labels=labels)
    cm_df_out = pd.DataFrame(
        cm, index=[f"T:{l}" for l in labels], columns=[f"P:{l}" for l in labels]
    )

    print(f"Rows evaluated: {len(cm_df)}  |  Unique labels: {len(labels)}")
    print("\nClassification report (micro/macro averages at bottom):")
    print(classification_report(y_true, y_pred, labels=labels, zero_division=0))

    display(cm_df_out.head(20))
    return (cm_df_out, labels, cm_df)


# Use it:
cm_df_out, labels_used, rows_used = cat3_confusion_and_report(out_df, top_n=40)
# Out:
# No rows where employee label is Cat3 — skipping confusion matrix.

# %% [markdown]
# ### 4.3 Save compact metrics JSON

# %%
metrics = {
    "overall_agreement_at_emp_tier": float(out_df["match_at_emp_tier"].mean()),
    "counts_by_emp_tier": out_df["emp_tier"].value_counts(dropna=False).to_dict(),
    "domain_breakdown": out_df.groupby("pred_domain")["match_at_emp_tier"]
    .mean()
    .sort_values(ascending=False)
    .to_dict(),
}
with open("metrics_summary.json", "w", encoding="utf-8") as f:
    json.dump(metrics, f, ensure_ascii=False, indent=2)
metrics
# Out:
# {'overall_agreement_at_emp_tier': 0.0,
#  'counts_by_emp_tier': {None: 21},
#  'domain_breakdown': {'IPTV': 0.0, 'Mobile': 0.0, 'Toki': 0.0}}

# %% [markdown]
# ## 5) Optional: spot-check disagreements

# %%
sample = out_df[out_df["match_at_emp_tier"] == False]
if len(sample) > 0:
    sample = sample.sample(min(10, len(sample)), random_state=42)
sample[
    [
        "case_id",
        "case",
        "ajiltan",
        "emp_tier",
        "pred_domain",
        "pred_cat1",
        "pred_cat2",
        "pred_cat3",
    ]
]
# Out:
#     case_id                                               case  \
# 0    145075  Gantuya': "Туслах цэс"\n'Unitel': "U-Bot-с хэр...
# 17   142619  Mishka Naraa': "Ажилтантай холбогдох"\n'tulga....
# 15   144724  Bayar BT': "хүрд яаж эргүүлэх вэ"\n'Unitel': "...
# 1    145050  Dx Bataa Baynmynkh Bataa': "Sain bnuu"\n'Unite...
# 8    144757  Panchi Panchi': "Get started"\n'Unitel': "Сайн...
# 5    144951  Huslee Huslen': "5k ymu 10k aar tseneglevel ur...
# 11   144970  Ану Ану': "Get Started"\n'Ану Ану': "Ажилтанта...
# 3    144958  Б. Нансалмаа': "Туслах цэс"\n'Unitel': "U-Bot-...
# 18   142568  Khishig Dorj': "Get started"\n'Khishig Dorj': ...
# 16   142692  Any Any': "Get started"\n'Any Any': "Ажилтанта...
#
#                                               ajiltan emp_tier pred_domain  \
# 0   Mobile > Үндсэн үйлчилгээ > Багц солихтой холб...     None      Mobile
# 17     Mobile > Төлбөр > Төлөлт, гүйлгээтэй холбоотой     None      Mobile
# 15  Mobile > Үндсэн үйлчилгээ > Урамшуулалтай холб...     None        Toki
# 1         Mobile > Дугаар > Дагалдах эрхтэй холбоотой     None      Mobile
# 8   Mobile > Үндсэн үйлчилгээ > Нэр шилжүүлэхтэй х...     None      Mobile
# 5         Mobile > Нэгж > Цэнэглэгч карттай холбоотой     None      Mobile
# 11      Mobile > Дугаар > Шинэ хэрэглэгчтэй холбоотой     None      Mobile
# 3          Mobile > Дугаар > Пин пук кодтой холбоотой     None      Mobile
# 18      Mobile > Дугаар > Шинэ хэрэглэгчтэй холбоотой     None      Mobile
# 16            Mobile > Дата > Зарцуулалттай холбоотой     None      Mobile
#
#            pred_cat1                          pred_cat2  \
# 0               Дата          Дата багцуудтай холбоотой
# 17            Дугаар  Дугаар хааж, нээлгэхтэй холбоотой
# 15       Toki Mobile                      Үндсэн нөхцөл
# 1             Дугаар  Дугаар хааж, нээлгэхтэй холбоотой
# 8   Нэмэлт үйлчилгээ        Unitel.mn тодорхойлолт авах
# 5               Нэгж    Цэнэглэлт, гүйлгээтэй холбоотой
# 11            Дугаар           Пин пук кодтой холбоотой
# 3             Дугаар           Сим сэргээхтэй холбоотой
# 18            Дугаар        Шинэ хэрэглэгчтэй холбоотой
# 16              Дата            Зарцуулалттай холбоотой
#
#                                             pred_cat3
# 0   L2- Дата багцын үнийн дүн зөрүүтэй харагдсанаа...
# 17  L2- Устах ёстой дугаар хугацаандаа устаагүйгээ...
# 15
# 1                             P-Дугаар нээлгэх хүсэлт
# 8
# 5   L2-Unitel app-р авсан нэгж ороогүйгээс шалтгаа...
# 11                           L1 - Пук код авах хүсэлт
# 3   L2-Unitel app сим сэргээхэд амжилтгүй алдаа за...
# 18  L2-Unitel app-с шинэ дугаар авахад алдаа заасн...
# 16  L2-Хэрэглэгч хэрэглээгээ хүлээн зөвшөөрөөгүйгэ...
